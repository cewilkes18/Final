# %%
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

spacex_df = pd.read_csv(r"C:\Users\Jeff\Desktop\pandas\spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

app = dash.Dash(__name__)



unique_launch_sites = spacex_df['Launch Site'].unique().tolist()
launch_sites = []
launch_sites.append({'label': 'All Sites', 'value': 'All Sites'})
for launch_site in unique_launch_sites:
    launch_sites.append({'label': launch_site, 'value': launch_site})

app.layout = html.Div(children=[
    html.Div([
        html.H1('SpaceX Launch Records Dashboard',
                style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
    ]),

    html.Div([
        # TASK 1: Add a Launch Site Drop-down Input Component
        dcc.Dropdown(
            id='site-dropdown',
            options=launch_sites,
            placeholder='Select a Launch Site here',
            searchable=True,
            clearable=False,
            value='All Sites'
        ),
        # TASK 2: Add a callback function to render success-pie-chart based on selected site dropdown
        html.Div(dcc.Graph(id='success-pie-chart')),
    ], style={'padding': '0 30px'}),

    html.Div([
        # TASK 3: Add a Range Slider to Select Payload
        html.Div("Payload range (Kg):",
                 style={'color': '#503D36', 'font-size': 20, 'padding': '0 30px', 'margin-left': '11px'}
                 ),
        html.Div([
            dcc.RangeSlider(
                id='payload_slider',
                min=0,
                max=10000,
                step=1000,
                marks={
                    0: {'label': '0 Kg', 'style': {'color': '#77b0b1'}},
                    1000: {'label': '1000 Kg'},
                    2000: {'label': '2000 Kg'},
                    3000: {'label': '3000 Kg'},
                    4000: {'label': '4000 Kg'},
                    5000: {'label': '5000 Kg'},
                    6000: {'label': '6000 Kg'},
                    7000: {'label': '7000 Kg'},
                    8000: {'label': '8000 Kg'},
                    9000: {'label': '9000 Kg'},
                    10000: {'label': '10000 Kg', 'style': {'color': '#f50'}},
                },
                value=[min_payload, max_payload]
            ),
        ], style={'padding': '40px 30px'}),

        # TASK 4: Add a callback function to render the success-payload-scatter-chart scatter plot
        html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ]),
], style={'padding': '0 20px'})


# TASK 2: success-pie-chart callback based on selected site dropdown
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value')]
)
def update_piegraph(site_dropdown):
    if (site_dropdown == 'All Sites' or site_dropdown == 'None'):
        all_sites = spacex_df[spacex_df['class'] == 1]  # All Success only for all sites.
        fig = px.pie(
            all_sites,
            names='Launch Site',
            title='Total Success Launches by All Sites',
            hole=.2,
            color_discrete_sequence=px.colors.sequential.RdBu
        )
    else:
        site_specific = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(
            site_specific,
            names='class',
            title='Total Success Launches for Site &#8608; ' + site_dropdown,
            hole=.2
        )
    return fig


# TASK 3, 4: Range Slider or Scatter Chart Callback
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'),
     Input(component_id="payload_slider", component_property="value")]
)
def update_scattergraph(site_dropdown, payload_slider):
    if (site_dropdown == 'All Sites' or site_dropdown == 'None'):
        low, high = payload_slider
        all_sites = spacex_df
        inrange = (all_sites['Payload Mass (kg)'] > low) & (all_sites['Payload Mass (kg)'] < high)
        fig = px.scatter(
            all_sites[inrange],
            x="Payload Mass (kg)",
            y="class",
            title='Correlation Between Payload and Success for All Sites',
            color="Booster Version Category",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)']
        )
    else:
        low, high = payload_slider
        site_specific = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        inrange = (site_specific['Payload Mass (kg)'] > low) & (site_specific['Payload Mass (kg)'] < high)
        fig = px.scatter(
            site_specific[inrange],
            x="Payload Mass (kg)",
            y="class",
            title='Correlation Between Payload and Success for Site &#8608; ' + site_dropdown,
            color="Booster Version Category",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)']
        )
    return fig


if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_3m1682554131.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_3m1682554131.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/deps/react@16.v2_9_3m1682554131.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_3m1682554131.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_3m1682554131.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_2m1682554131.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_2m1682554131.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_11m1682554131.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_4m1682554131.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# [2023-04-26 17:11:35,368] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:11:35] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:11:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# [2023-04-26 17:19:51,159] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:51] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# [2023-04-26 17:19:54,525] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:19:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:19:54] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:19:57] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:19:57,962] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:19:57] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# [2023-04-26 17:20:00,219] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:20:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:00] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# [2023-04-26 17:20:26,495] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:26] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# [2023-04-26 17:20:36,816] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:20:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:20:36] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:20:39] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:20:39,014] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:20:39] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# [2023-04-26 17:24:12,829] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:24:12] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:24:21] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:24:25] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:24:25,152] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:24:25] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:24:27] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:24:27,391] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:24:27] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:24:35] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:24:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# [2023-04-26 17:25:32,252] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:32] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:25:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:25:51] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:25:54] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:25:54,572] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:25:54] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:27:46] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:27:46,206] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:27:46] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# [2023-04-26 17:27:47,831] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:27:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:27:47] "POST /_dash-update-component HTTP/1.1" 500 -
# C:\Users\Jeff\AppData\Local\Temp\ipykernel_17440\2977792656.py:15: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [26/Apr/2023 17:27:49] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-04-26 17:27:49,972] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# 127.0.0.1 - - [26/Apr/2023 17:27:49] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1[2023-04-26 17:28:03,573] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1231, in dispatch
#     func = cb["callback"]
# KeyError: 'callback'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Jeff\anaconda3\envs\pandas_playground\lib\site-packages\dash\dash.py", line 1279, in dispatch
#     raise KeyError(msg) from missing_callback_function
# KeyError: "Callback function not found for output 'success-pie-chart.figure', perhaps you forgot to prepend the '@'?"
# " 304 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Apr/2023 17:28:03] "POST /_dash-update-component HTTP/1.1" 500 -
